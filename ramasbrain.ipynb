# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

from scipy.stats import linregress
import seaborn as sns

plt.style.use('fivethirtyeight')
import ipywidgets as widgets
# %matplotlib inline
from ipywidgets import interact, interactive, fixed, interact_manual

# %%
# https://neuroelectro.org/api/docs/
neuro = pd.read_csv('article_ephys_metadata_curated.csv',sep='\t')
neuro = neuro.dropna(axis=1)

# %%
neuro.head(3)
# Out:
#    Index                                              Title      Pmid  \
# 0    150  Cell type-specific effects of adenosine on cor...  24108800
# 1    149  Cell type-specific effects of adenosine on cor...  24108800
# 2    151  Cell type-specific effects of adenosine on cor...  24108800
#
#    PubYear   LastAuthor  ArticleID                 NeuronName  \
# 0     2015  Feldmeyer D      88449      Neocortex basket cell
# 1     2015  Feldmeyer D      88449  Neocortex Martinotti cell
# 2     2015  Feldmeyer D      88449      Neocortex basket cell
#
#                                       NeuronPrefName  \
# 0   medial prefrontal cortex fast spiking interne...
# 1  medial prefrontal cortex low-threshold spiking...
# 2       somatosensory cortex fast-firing interneuron
#
#                                       NeuroNERAnnots  MetadataCurated
# 0  [ABA_REGION:714, HBP_EPHYS:0000080, HBP_EPHYS_...             True
# 1  [ABA_REGION:714, HBP_EPHYS:0000110, HBP_EPHYS_...             True
# ...

# %%
cell_diversity = pd.read_csv('sample_annotations.csv')
cell_diversity = cell_diversity.dropna(axis=1,how='all')
# useful columns: class_label,subclass_label,donor_sex_order,donor_sex_label,maybe: region_order,region_label,
#  maybe:cortical_layer_order, cortical_layer_label,maybe:cell_type_accession_order,

# %%
cell_diversity['region_label'].value_counts()
# Out:
# MTG     16232
# V1C      8052
# A1C      6703
# CgG      6279
# M1lm     3371
# S1ul     3188
# M1ul     2864
# S1lm     2805
# Name: region_label, dtype: int64

# %%
cell_diversity.head(3)
# Out:
#            sample_name cluster_color  cluster_order             cluster_label  \
# 0  LS-15005h_S01_E1-50          grey            126  Outlier L1-3 SST OR2AD1P
# 1  LS-15005h_S02_E1-50       #E170FE             32         Inh L2-5 VIP TOX2
# 2  LS-15005h_S03_E1-50       #8E5864              2        Inh L1 LAMP5 GGT8P
#
#   class_color  class_order class_label subclass_color  subclass_order  \
# 0     #B65CCC            5     Exclude        #CC003D              20
# 1     #0066FF            4   GABAergic        #996517               3
# 2     #0066FF            4   GABAergic        #FF7373               1
#
#   subclass_label            ...                cell_type_alias_label  \
# 0        Exclude            ...             Outlier L1-3 SST OR2AD1P
# 1            VIP            ...                    Inh L2-5 VIP TOX2
# 2          LAMP5            ...                   Inh L1 LAMP5 GGT8P
#
#    cell_type_alt_alias_color cell_type_alt_alias_order  \
# ...
